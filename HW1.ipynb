# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/births/US_births_2000-2014_SSA.csv')
df
# Out:
#       year  month  date_of_month  day_of_week  births
# 0     2000      1              1            6    9083
# 1     2000      1              2            7    8006
# 2     2000      1              3            1   11363
# 3     2000      1              4            2   13032
# 4     2000      1              5            3   12558
# ...    ...    ...            ...          ...     ...
# 5474  2014     12             27            6    8656
# 5475  2014     12             28            7    7724
# 5476  2014     12             29            1   12811
# 5477  2014     12             30            2   13634
# 5478  2014     12             31            3   11990
#
# [5479 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
np.mean(df['births'])
plt.scatter(df['day_of_week'], df['births'])
plt.xlabel('day of week')
plt.ylabel('# of births');

# %%
grp = df.groupby('date_of_month')
birth_by_date = grp.mean()

plt.plot(birth_by_date.index, birth_by_date.births)
plt.xlabel('date of month')
plt.ylabel('avg. births per day');

# %%
year_grp = df.groupby('year')
year_grp.sum()
# Out:
#       month  date_of_month  day_of_week   births
# year
# 2000   2384           5767         1469  4149598
# 2001   2382           5738         1457  4110963
# 2002   2382           5738         1458  4099313
# 2003   2382           5738         1459  4163060
# 2004   2384           5767         1465  4186863
# 2005   2382           5738         1462  4211941
# 2006   2382           5738         1463  4335154
# 2007   2382           5738         1457  4380784
# 2008   2384           5767         1461  4310737
# 2009   2382           5738         1460  4190991
# 2010   2382           5738         1461  4055975
# 2011   2382           5738         1462  4006908
# 2012   2384           5767         1464  4000868
# 2013   2382           5738         1458  3973337
# 2014   2382           5738         1459  4010532

# %%
births_by_year = year_grp.sum()

plt.plot(births_by_year.index, births_by_year.births)
plt.ylabel('# of births')
plt.xlabel('year')
plt.axvline(2008)
#2008 was the US recession, we see a dramatic drop in births after this year, meaning there is a large correlation between economy and number of births

# %%
first_day_sel = (df['date_of_month'] == 1) | (df['date_of_month'] == 2)

first_day_grp = df[first_day_sel].groupby('month')
first_day_birth_by_month = first_day_grp.mean()

plt.plot(first_day_birth_by_month.index, first_day_birth_by_month.births)
plt.xlabel('month')
plt.ylabel('avg. births per day');

#here we can see that people do not like to have children the first day of the month apparently, and tend to have them later on

# %%
df=pd.read_csv('data/tmdb_5000_credits.csv')
df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
plt.hist(df['movie_id'])
plt.xlabel('# of movies each id')
plt.ylabel('counts');

#I honestly didn't really understand this data set, as the values were a bit strange, but i made a histogram
